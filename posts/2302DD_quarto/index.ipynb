# %% [raw]
# ---
# title: "Quarto"
# from: markdown+emoji
# author: "Torodd F. Ottestad"
# date: "2023-02"
# categories: [verktøy, programmering, tips]
# image: "quarto.jpg"
# draft: true
# ---

# %% [markdown]
# # Quarto
#
# Bla bla
